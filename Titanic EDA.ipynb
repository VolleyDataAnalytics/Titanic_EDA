# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
# In \[2\]:
#
#     df = pd.read_csv('train.csv')
#
# In \[3\]:
#
#     df.head()
#
# Out\[3\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket           | Fare    | Cabin | Embarked |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|------------------|---------|-------|----------|
# | 0   | 1           | 0        | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171        | 7.2500  | NaN   | S        |
# | 1   | 2           | 1        | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599         | 71.2833 | C85   | C        |
# | 2   | 3           | 1        | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282 | 7.9250  | NaN   | S        |
# | 3   | 4           | 1        | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803           | 53.1000 | C123  | S        |
# | 4   | 5           | 0        | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450           | 8.0500  | NaN   | S        |
#
# AGE (UNIVARIATE ANALYSIS) CONCLUSION ..Age is normally distributed ..20%
# of the values are missing .. there are some outliers
#
# In \[4\]:
#
#     df['Age'].describe()
#
# Out\[4\]:
#
#     count    714.000000
#     mean      29.699118
#     std       14.526497
#     min        0.420000
#     25%       20.125000
#     50%       28.000000
#     75%       38.000000
#     max       80.000000
#     Name: Age, dtype: float64
#
# In \[5\]:
#
#     df['Age'].plot(kind ='hist',bins=20)
#
# Out\[5\]:
#
#     <Axes: ylabel='Frequency'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[6\]:
#
#     df['Age'].plot(kind ='kde')
#
# Out\[6\]:
#
#     <Axes: ylabel='Density'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[7\]:
#
#     df['Age'].skew()
#
# Out\[7\]:
#
#     0.38910778230082704
#
# In \[10\]:
#
#     df['Age'].plot(kind ='box')
#
# Out\[10\]:
#
#     <Axes: >
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[11\]:
#
#     df[df['Age']>65]
#
# Out\[11\]:
#
# |     | PassengerId | Survived | Pclass | Name                                 | Sex  | Age  | SibSp | Parch | Ticket     | Fare    | Cabin | Embarked |
# |-----|-------------|----------|--------|--------------------------------------|------|------|-------|-------|------------|---------|-------|----------|
# | 33  | 34          | 0        | 2      | Wheadon, Mr. Edward H                | male | 66.0 | 0     | 0     | C.A. 24579 | 10.5000 | NaN   | S        |
# | 96  | 97          | 0        | 1      | Goldschmidt, Mr. George B            | male | 71.0 | 0     | 0     | PC 17754   | 34.6542 | A5    | C        |
# | 116 | 117         | 0        | 3      | Connors, Mr. Patrick                 | male | 70.5 | 0     | 0     | 370369     | 7.7500  | NaN   | Q        |
# | 493 | 494         | 0        | 1      | Artagaveytia, Mr. Ramon              | male | 71.0 | 0     | 0     | PC 17609   | 49.5042 | NaN   | C        |
# | 630 | 631         | 1        | 1      | Barkworth, Mr. Algernon Henry Wilson | male | 80.0 | 0     | 0     | 27042      | 30.0000 | A23   | S        |
# | 672 | 673         | 0        | 2      | Mitchell, Mr. Henry Michael          | male | 70.0 | 0     | 0     | C.A. 24580 | 10.5000 | NaN   | S        |
# | 745 | 746         | 0        | 1      | Crosby, Capt. Edward Gifford         | male | 70.0 | 1     | 1     | WE/P 5735  | 71.0000 | B22   | S        |
# | 851 | 852         | 0        | 3      | Svensson, Mr. Johan                  | male | 74.0 | 0     | 0     | 347060     | 7.7750  | NaN   | S        |
#
# In \[8\]:
#
#     df['Age'].isnull().sum()/len(df['Age'])
#
# Out\[8\]:
#
#     0.19865319865319866
#
# Fare conclusions 1.The data is highly postively skewed 2.fair column
# actual contains group fare and not the indiviual fare(This might be an
# issue ) 3.we need to create a new column called indiviual fare
#
# In \[9\]:
#
#     df['Fare'].describe()
#
# Out\[9\]:
#
#     count    891.000000
#     mean      32.204208
#     std       49.693429
#     min        0.000000
#     25%        7.910400
#     50%       14.454200
#     75%       31.000000
#     max      512.329200
#     Name: Fare, dtype: float64
#
# In \[15\]:
#
#     df['Fare'].plot(kind ='hist')
#
# Out\[15\]:
#
#     <Axes: ylabel='Frequency'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[17\]:
#
#     df['Fare'].plot(kind ='kde')
#
# Out\[17\]:
#
#     <Axes: ylabel='Density'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[18\]:
#
#     df['Fare'].skew()
#
# Out\[18\]:
#
#     4.787316519674893
#
# In \[19\]:
#
#     df['Fare'].plot(kind ='box')
#
# Out\[19\]:
#
#     <Axes: >
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# df\[df\['Fare'\] \>230\]
#
# In \[25\]:
#
#     df['Fare'].isnull()
#
# Out\[25\]:
#
#     0      False
#     1      False
#     2      False
#     3      False
#     4      False
#            ...
#     886    False
#     887    False
#     888    False
#     889    False
#     890    False
#     Name: Fare, Length: 891, dtype: bool
#
# SURVIVED Conclusion
#
# 1.  more than 50% people are died and less than30% survied
# 2.  there are 543 people died and 342 people survied
#
# In \[10\]:
#
#     df['Survived'].value_counts()
#
# Out\[10\]:
#
#     Survived
#     0    549
#     1    342
#     Name: count, dtype: int64
#
# In \[29\]:
#
#     df['Survived'].value_counts().plot(kind ='bar')
#
# Out\[29\]:
#
#     <Axes: xlabel='Survived'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[31\]:
#
#     df['Survived'].value_counts().plot(kind= 'pie',autopct ='%0.1f%%')
#
# Out\[31\]:
#
#     <Axes: ylabel='count'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[32\]:
#
#     df['Survived'].isnull()
#
# Out\[32\]:
#
#     0      False
#     1      False
#     2      False
#     3      False
#     4      False
#            ...
#     886    False
#     887    False
#     888    False
#     889    False
#     890    False
#     Name: Survived, Length: 891, dtype: bool
#
# PCLASS Coclusion 1.more people travelled in 3 class and less in 1 and 2
# why?
#
# SEX conclusion there are 64% male and 35 % female
#
# Sibsp conclusion more pepole travelling with no siblings
#
# Parch conclusion more people without parent
#
# IMP Parch and Sibsp can mergered can be merged to form a new col
# family_size create a new column called alone
#
# Embarked start se sbse jada the
#
# MIXED COLUMNS need to feature engineer
#
# In \[33\]:
#
#     df
#
# Out\[33\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket           | Fare    | Cabin | Embarked |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|------------------|---------|-------|----------|
# | 0   | 1           | 0        | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171        | 7.2500  | NaN   | S        |
# | 1   | 2           | 1        | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599         | 71.2833 | C85   | C        |
# | 2   | 3           | 1        | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282 | 7.9250  | NaN   | S        |
# | 3   | 4           | 1        | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803           | 53.1000 | C123  | S        |
# | 4   | 5           | 0        | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450           | 8.0500  | NaN   | S        |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...              | ...     | ...   | ...      |
# | 886 | 887         | 0        | 2      | Montvila, Rev. Juozas                             | male   | 27.0 | 0     | 0     | 211536           | 13.0000 | NaN   | S        |
# | 887 | 888         | 1        | 1      | Graham, Miss. Margaret Edith                      | female | 19.0 | 0     | 0     | 112053           | 30.0000 | B42   | S        |
# | 888 | 889         | 0        | 3      | Johnston, Miss. Catherine Helen "Carrie"          | female | NaN  | 1     | 2     | W./C. 6607       | 23.4500 | NaN   | S        |
# | 889 | 890         | 1        | 1      | Behr, Mr. Karl Howell                             | male   | 26.0 | 0     | 0     | 111369           | 30.0000 | C148  | C        |
# | 890 | 891         | 0        | 3      | Dooley, Mr. Patrick                               | male   | 32.0 | 0     | 0     | 370376           | 7.7500  | NaN   | Q        |
#
# 891 rows × 12 columns
#
# There is two imp columns survived and age because in age there is
# missing columns
#
# In \[34\]:
#
#     pd.crosstab(df['Survived'],df['Pclass'])
#
# Out\[34\]:
#
# | Pclass   | 1   | 2   | 3   |
# |----------|-----|-----|-----|
# | Survived |     |     |     |
# | 0        | 80  | 97  | 372 |
# | 1        | 136 | 87  | 119 |
#
# In \[37\]:
#
#     pd.crosstab(df['Survived'],df['Pclass'],normalize ='columns')*100
#
# Out\[37\]:
#
# | Pclass   | 1         | 2         | 3         |
# |----------|-----------|-----------|-----------|
# | Survived |           |           |           |
# | 0        | 37.037037 | 52.717391 | 75.763747 |
# | 1        | 62.962963 | 47.282609 | 24.236253 |
#
# In \[40\]:
#
#     sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize ='columns')*100)
#
# Out\[40\]:
#
#     <Axes: xlabel='Pclass', ylabel='Survived'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[41\]:
#
#     pd.crosstab(df['Survived'],df['Sex'],normalize ='columns')*100
#
# Out\[41\]:
#
# | Sex      | female    | male      |
# |----------|-----------|-----------|
# | Survived |           |           |
# | 0        | 25.796178 | 81.109185 |
# | 1        | 74.203822 | 18.890815 |
#
# In \[42\]:
#
#     pd.crosstab(df['Survived'],df['Embarked'],normalize ='columns')*100
#
# Out\[42\]:
#
# | Embarked | C         | Q         | S         |
# |----------|-----------|-----------|-----------|
# | Survived |           |           |           |
# | 0        | 44.642857 | 61.038961 | 66.304348 |
# | 1        | 55.357143 | 38.961039 | 33.695652 |
#
# In \[47\]:
#
#     df[df['Survived'] ==1]['Age'].plot(kind ='kde',label= 'Survived')
#     df[df['Survived'] ==0]['Age'].plot(kind ='kde',label ='NOT survived')
#     plt.legend()
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[48\]:
#
#     df[df['Pclass'] == 1]['Age'].mean()
#
# Out\[48\]:
#
#     38.233440860215055
#
# In \[50\]:
#
#     df['SibSp'].value_counts()
#
# Out\[50\]:
#
#     SibSp
#     0    608
#     1    209
#     2     28
#     4     18
#     3     16
#     8      7
#     5      5
#     Name: count, dtype: int64
#
# In \[51\]:
#
#     df[df['SibSp'] == 8]
#
# Out\[51\]:
#
# |     | PassengerId | Survived | Pclass | Name                              | Sex    | Age | SibSp | Parch | Ticket   | Fare  | Cabin | Embarked |
# |-----|-------------|----------|--------|-----------------------------------|--------|-----|-------|-------|----------|-------|-------|----------|
# | 159 | 160         | 0        | 3      | Sage, Master. Thomas Henry        | male   | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 180 | 181         | 0        | 3      | Sage, Miss. Constance Gladys      | female | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 201 | 202         | 0        | 3      | Sage, Mr. Frederick               | male   | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 324 | 325         | 0        | 3      | Sage, Mr. George John Jr          | male   | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 792 | 793         | 0        | 3      | Sage, Miss. Stella Anna           | female | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 846 | 847         | 0        | 3      | Sage, Mr. Douglas Bullen          | male   | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
# | 863 | 864         | 0        | 3      | Sage, Miss. Dorothy Edith "Dolly" | female | NaN | 8     | 2     | CA. 2343 | 69.55 | NaN   | S        |
#
# In \[53\]:
#
#     df1 = pd.read_csv('test.csv')
#
# In \[54\]:
#
#     df1
#
# Out\[54\]:
#
# |     | PassengerId | Pclass | Name                                         | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked |
# |-----|-------------|--------|----------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|
# | 0   | 892         | 3      | Kelly, Mr. James                             | male   | 34.5 | 0     | 0     | 330911             | 7.8292   | NaN   | Q        |
# | 1   | 893         | 3      | Wilkes, Mrs. James (Ellen Needs)             | female | 47.0 | 1     | 0     | 363272             | 7.0000   | NaN   | S        |
# | 2   | 894         | 2      | Myles, Mr. Thomas Francis                    | male   | 62.0 | 0     | 0     | 240276             | 9.6875   | NaN   | Q        |
# | 3   | 895         | 3      | Wirz, Mr. Albert                             | male   | 27.0 | 0     | 0     | 315154             | 8.6625   | NaN   | S        |
# | 4   | 896         | 3      | Hirvonen, Mrs. Alexander (Helga E Lindqvist) | female | 22.0 | 1     | 1     | 3101298            | 12.2875  | NaN   | S        |
# | ... | ...         | ...    | ...                                          | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      |
# | 413 | 1305        | 3      | Spector, Mr. Woolf                           | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | NaN   | S        |
# | 414 | 1306        | 1      | Oliva y Ocana, Dona. Fermina                 | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        |
# | 415 | 1307        | 3      | Saether, Mr. Simon Sivertsen                 | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | NaN   | S        |
# | 416 | 1308        | 3      | Ware, Mr. Frederick                          | male   | NaN  | 0     | 0     | 359309             | 8.0500   | NaN   | S        |
# | 417 | 1309        | 3      | Peter, Master. Michael J                     | male   | NaN  | 1     | 1     | 2668               | 22.3583  | NaN   | C        |
#
# 418 rows × 11 columns
#
# In \[55\]:
#
#     df = pd.concat([df,df1])
#
# In \[56\]:
#
#     df
#
# Out\[56\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|
# | 0   | 1           | 0.0      | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171          | 7.2500   | NaN   | S        |
# | 1   | 2           | 1.0      | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599           | 71.2833  | C85   | C        |
# | 2   | 3           | 1.0      | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282   | 7.9250   | NaN   | S        |
# | 3   | 4           | 1.0      | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803             | 53.1000  | C123  | S        |
# | 4   | 5           | 0.0      | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450             | 8.0500   | NaN   | S        |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      |
# | 413 | 1305        | NaN      | 3      | Spector, Mr. Woolf                                | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | NaN   | S        |
# | 414 | 1306        | NaN      | 1      | Oliva y Ocana, Dona. Fermina                      | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        |
# | 415 | 1307        | NaN      | 3      | Saether, Mr. Simon Sivertsen                      | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | NaN   | S        |
# | 416 | 1308        | NaN      | 3      | Ware, Mr. Frederick                               | male   | NaN  | 0     | 0     | 359309             | 8.0500   | NaN   | S        |
# | 417 | 1309        | NaN      | 3      | Peter, Master. Michael J                          | male   | NaN  | 1     | 1     | 2668               | 22.3583  | NaN   | C        |
#
# 1309 rows × 12 columns
#
# In \[60\]:
#
#     df['Indiviual fare'] = df['Fare']/(df['SibSp'] + df['Parch'] +1)
#
# In \[62\]:
#
#     df['Indiviual fare'].plot(kind ='box')
#
# Out\[62\]:
#
#     <Axes: >
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[63\]:
#
#     df['Indiviual fare'].describe()
#
# Out\[63\]:
#
#     count    1308.000000
#     mean       20.518215
#     std        35.774337
#     min         0.000000
#     25%         7.452767
#     50%         8.512483
#     75%        24.237500
#     max       512.329200
#     Name: Indiviual fare, dtype: float64
#
# In \[64\]:
#
#     df['Fare'].describe()
#
# Out\[64\]:
#
#     count    1308.000000
#     mean       33.295479
#     std        51.758668
#     min         0.000000
#     25%         7.895800
#     50%        14.454200
#     75%        31.275000
#     max       512.329200
#     Name: Fare, dtype: float64
#
# In \[65\]:
#
#     df
#
# Out\[65\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked | Indiviual fare |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|----------------|
# | 0   | 1           | 0.0      | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171          | 7.2500   | NaN   | S        | 3.625000       |
# | 1   | 2           | 1.0      | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599           | 71.2833  | C85   | C        | 35.641650      |
# | 2   | 3           | 1.0      | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282   | 7.9250   | NaN   | S        | 7.925000       |
# | 3   | 4           | 1.0      | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803             | 53.1000  | C123  | S        | 26.550000      |
# | 4   | 5           | 0.0      | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450             | 8.0500   | NaN   | S        | 8.050000       |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      | ...            |
# | 413 | 1305        | NaN      | 3      | Spector, Mr. Woolf                                | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | NaN   | S        | 8.050000       |
# | 414 | 1306        | NaN      | 1      | Oliva y Ocana, Dona. Fermina                      | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        | 108.900000     |
# | 415 | 1307        | NaN      | 3      | Saether, Mr. Simon Sivertsen                      | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | NaN   | S        | 7.250000       |
# | 416 | 1308        | NaN      | 3      | Ware, Mr. Frederick                               | male   | NaN  | 0     | 0     | 359309             | 8.0500   | NaN   | S        | 8.050000       |
# | 417 | 1309        | NaN      | 3      | Peter, Master. Michael J                          | male   | NaN  | 1     | 1     | 2668               | 22.3583  | NaN   | C        | 7.452767       |
#
# 1309 rows × 13 columns
#
# In \[68\]:
#
#     df['family size'] = df['SibSp'] +df['Parch'] +1
#
# In \[69\]:
#
#     df
#
# Out\[69\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked | Indiviual fare | family size |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|----------------|-------------|
# | 0   | 1           | 0.0      | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171          | 7.2500   | NaN   | S        | 3.625000       | 2           |
# | 1   | 2           | 1.0      | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599           | 71.2833  | C85   | C        | 35.641650      | 2           |
# | 2   | 3           | 1.0      | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282   | 7.9250   | NaN   | S        | 7.925000       | 1           |
# | 3   | 4           | 1.0      | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803             | 53.1000  | C123  | S        | 26.550000      | 2           |
# | 4   | 5           | 0.0      | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450             | 8.0500   | NaN   | S        | 8.050000       | 1           |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      | ...            | ...         |
# | 413 | 1305        | NaN      | 3      | Spector, Mr. Woolf                                | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | NaN   | S        | 8.050000       | 1           |
# | 414 | 1306        | NaN      | 1      | Oliva y Ocana, Dona. Fermina                      | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        | 108.900000     | 1           |
# | 415 | 1307        | NaN      | 3      | Saether, Mr. Simon Sivertsen                      | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | NaN   | S        | 7.250000       | 1           |
# | 416 | 1308        | NaN      | 3      | Ware, Mr. Frederick                               | male   | NaN  | 0     | 0     | 359309             | 8.0500   | NaN   | S        | 8.050000       | 1           |
# | 417 | 1309        | NaN      | 3      | Peter, Master. Michael J                          | male   | NaN  | 1     | 1     | 2668               | 22.3583  | NaN   | C        | 7.452767       | 3           |
#
# 1309 rows × 14 columns
#
# In \[70\]:
#
#     def transform_family_size(num):
#         if num == 1:
#             return 'alone'
#         elif num >1 and num< 5:
#             return 'small'
#         else:
#             return 'large'
#
# In \[71\]:
#
#     df['family type'] =df['family size'].apply(transform_family_size)
#
# In \[72\]:
#
#     df
#
# Out\[72\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked | Indiviual fare | family size | family type |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|----------------|-------------|-------------|
# | 0   | 1           | 0.0      | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171          | 7.2500   | NaN   | S        | 3.625000       | 2           | small       |
# | 1   | 2           | 1.0      | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599           | 71.2833  | C85   | C        | 35.641650      | 2           | small       |
# | 2   | 3           | 1.0      | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282   | 7.9250   | NaN   | S        | 7.925000       | 1           | alone       |
# | 3   | 4           | 1.0      | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803             | 53.1000  | C123  | S        | 26.550000      | 2           | small       |
# | 4   | 5           | 0.0      | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450             | 8.0500   | NaN   | S        | 8.050000       | 1           | alone       |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      | ...            | ...         | ...         |
# | 413 | 1305        | NaN      | 3      | Spector, Mr. Woolf                                | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | NaN   | S        | 8.050000       | 1           | alone       |
# | 414 | 1306        | NaN      | 1      | Oliva y Ocana, Dona. Fermina                      | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        | 108.900000     | 1           | alone       |
# | 415 | 1307        | NaN      | 3      | Saether, Mr. Simon Sivertsen                      | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | NaN   | S        | 7.250000       | 1           | alone       |
# | 416 | 1308        | NaN      | 3      | Ware, Mr. Frederick                               | male   | NaN  | 0     | 0     | 359309             | 8.0500   | NaN   | S        | 8.050000       | 1           | alone       |
# | 417 | 1309        | NaN      | 3      | Peter, Master. Michael J                          | male   | NaN  | 1     | 1     | 2668               | 22.3583  | NaN   | C        | 7.452767       | 3           | small       |
#
# 1309 rows × 15 columns
#
# In \[75\]:
#
#     pd.crosstab(df['Survived'],df['family type'],normalize ='columns')*100
#
# Out\[75\]:
#
# | family type | alone     | large     | small     |
# |-------------|-----------|-----------|-----------|
# | Survived    |           |           |           |
# | 0.0         | 69.646182 | 83.870968 | 42.123288 |
# | 1.0         | 30.353818 | 16.129032 | 57.876712 |
#
# In \[76\]:
#
#     df['Cabin'].value_counts().head(15)
#
# Out\[76\]:
#
#     Cabin
#     C23 C25 C27        6
#     G6                 5
#     B57 B59 B63 B66    5
#     C22 C26            4
#     F33                4
#     F2                 4
#     B96 B98            4
#     C78                4
#     F4                 4
#     D                  4
#     E34                3
#     B58 B60            3
#     A34                3
#     E101               3
#     C101               3
#     Name: count, dtype: int64
#
# In \[77\]:
#
#     df['Cabin'].fillna('M' ,inplace =True)
#
# In \[78\]:
#
#     df['Cabin'].value_counts().head(15)
#
# Out\[78\]:
#
#     Cabin
#     M                  1014
#     C23 C25 C27           6
#     B57 B59 B63 B66       5
#     G6                    5
#     F33                   4
#     D                     4
#     C78                   4
#     B96 B98               4
#     F4                    4
#     F2                    4
#     C22 C26               4
#     E34                   3
#     B51 B53 B55           3
#     E101                  3
#     A34                   3
#     Name: count, dtype: int64
#
# In \[80\]:
#
#     df['deck'] =df['Cabin'].str[0]
#
# In \[81\]:
#
#     df
#
# Out\[81\]:
#
# |     | PassengerId | Survived | Pclass | Name                                              | Sex    | Age  | SibSp | Parch | Ticket             | Fare     | Cabin | Embarked | Indiviual fare | family size | family type | deck |
# |-----|-------------|----------|--------|---------------------------------------------------|--------|------|-------|-------|--------------------|----------|-------|----------|----------------|-------------|-------------|------|
# | 0   | 1           | 0.0      | 3      | Braund, Mr. Owen Harris                           | male   | 22.0 | 1     | 0     | A/5 21171          | 7.2500   | M     | S        | 3.625000       | 2           | small       | M    |
# | 1   | 2           | 1.0      | 1      | Cumings, Mrs. John Bradley (Florence Briggs Th... | female | 38.0 | 1     | 0     | PC 17599           | 71.2833  | C85   | C        | 35.641650      | 2           | small       | C    |
# | 2   | 3           | 1.0      | 3      | Heikkinen, Miss. Laina                            | female | 26.0 | 0     | 0     | STON/O2. 3101282   | 7.9250   | M     | S        | 7.925000       | 1           | alone       | M    |
# | 3   | 4           | 1.0      | 1      | Futrelle, Mrs. Jacques Heath (Lily May Peel)      | female | 35.0 | 1     | 0     | 113803             | 53.1000  | C123  | S        | 26.550000      | 2           | small       | C    |
# | 4   | 5           | 0.0      | 3      | Allen, Mr. William Henry                          | male   | 35.0 | 0     | 0     | 373450             | 8.0500   | M     | S        | 8.050000       | 1           | alone       | M    |
# | ... | ...         | ...      | ...    | ...                                               | ...    | ...  | ...   | ...   | ...                | ...      | ...   | ...      | ...            | ...         | ...         | ...  |
# | 413 | 1305        | NaN      | 3      | Spector, Mr. Woolf                                | male   | NaN  | 0     | 0     | A.5. 3236          | 8.0500   | M     | S        | 8.050000       | 1           | alone       | M    |
# | 414 | 1306        | NaN      | 1      | Oliva y Ocana, Dona. Fermina                      | female | 39.0 | 0     | 0     | PC 17758           | 108.9000 | C105  | C        | 108.900000     | 1           | alone       | C    |
# | 415 | 1307        | NaN      | 3      | Saether, Mr. Simon Sivertsen                      | male   | 38.5 | 0     | 0     | SOTON/O.Q. 3101262 | 7.2500   | M     | S        | 7.250000       | 1           | alone       | M    |
# | 416 | 1308        | NaN      | 3      | Ware, Mr. Frederick                               | male   | NaN  | 0     | 0     | 359309             | 8.0500   | M     | S        | 8.050000       | 1           | alone       | M    |
# | 417 | 1309        | NaN      | 3      | Peter, Master. Michael J                          | male   | NaN  | 1     | 1     | 2668               | 22.3583  | M     | C        | 7.452767       | 3           | small       | M    |
#
# 1309 rows × 16 columns
#
# In \[82\]:
#
#     pd.crosstab(df['deck'],df['Pclass'])
#
# Out\[82\]:
#
# | Pclass | 1   | 2   | 3   |
# |--------|-----|-----|-----|
# | deck   |     |     |     |
# | A      | 22  | 0   | 0   |
# | B      | 65  | 0   | 0   |
# | C      | 94  | 0   | 0   |
# | D      | 40  | 6   | 0   |
# | E      | 34  | 4   | 3   |
# | F      | 0   | 13  | 8   |
# | G      | 0   | 0   | 5   |
# | M      | 67  | 254 | 693 |
# | T      | 1   | 0   | 0   |
#
# In \[84\]:
#
#     pd.crosstab(df['Survived'],df['deck'],normalize = 'columns').plot
#
# Out\[84\]:
#
# | deck     | A        | B        | C       | D        | E    | F        | G   | M        | T   |
# |----------|----------|----------|---------|----------|------|----------|-----|----------|-----|
# | Survived |          |          |         |          |      |          |     |          |     |
# | 0.0      | 0.533333 | 0.255319 | 0.40678 | 0.242424 | 0.25 | 0.384615 | 0.5 | 0.700146 | 1.0 |
# | 1.0      | 0.466667 | 0.744681 | 0.59322 | 0.757576 | 0.75 | 0.615385 | 0.5 | 0.299854 | 0.0 |
#
# In \[ \]:
